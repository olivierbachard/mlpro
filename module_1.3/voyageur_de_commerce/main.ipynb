# %% [markdown]
# # Exercice voyageur de commerce
#
# Durée : 1 heure
# ### Sujet de lʼexamen
# Vous êtes chargé de résoudre un problème dʼoptimisation simplifié inspiré du Voyageur de Commerce (TSP). On vous fournit une liste de villes sous forme de nœuds avec leurs
# coordonnées (x,y), et vous devez :
#
# #### Charger et représenter les données
# On vous donne un fichier texte villes.txt contenant sur chaque ligne :
# ```
# NomVille X Y
# ```
# Par exemple :
# ```
# Paris 48.8567 2.3522
# Bordeaux 44.84 -0.58
# Marseille 43.2964 5.37
# ...
# ```
# - Écrire une fonction charger_villes(chemin) qui prend en paramètre le chemin du fichier (ex : “villes.txt”) et retourne une liste de tuples (NomVille, X, Y).
# - Afficher la liste des villes chargées ainsi que leur nombre total.
#
# #### Calcul des distances
# Vous allez implémenter un calcul de distance Euclidienne entre deux villes.
#
# - Écrire une fonction distance(villeA, villeB) qui, étant donné deux tuples (NomVille, X, Y), retourne la distance Euclidienne entre elles.
# - Tester votre fonction en affichant la distance entre au moins 2 paires de villes de votre liste.
#
# #### Heuristique simple pour le Voyageur de Commerce
# Le but ici nʼest pas de résoudre parfaitement le TSP, mais de proposer une heuristique simple : partir de la première ville de la liste, puis à chaque étape, aller à la ville la plus proche non encore visitée. Continuer jusquʼà avoir visité toutes les villes.
#
# - Écrire une fonction itineraire_greedy(villes) qui, donnée la liste de villes, retourne une liste représentant lʼordre des visites de ces villes selon lʼheuristique décrite (une liste de tuples ou de noms de villes).
# - Afficher lʼordre proposé par lʼalgorithme.
#
# #### Affichage et analyse
# - Afficher un récapitulatif : nombre total de villes, itinéraire trouvé, distance totale.
# - Discuter brièvement (en commentaire dans le code) des limites de cette approche heuristique. Par exemple : pourquoi nʼest-elle pas optimale ? Quels sont les problèmes éventuels de cette méthode sur un plus grand ensemble de villes ?

# %% [markdown]
# #### Charger et représenter les données

# %%
import shlex

# Define a class Ville which represents a city with its coordinates
class Ville:

   def __init__(self, name, longitude, latitude):
      self.name = name
      self.longitude = longitude
      self.latitude = latitude

   def __str__(self):
      return f"{self.name}({self.longitude},{self.latitude})"

def charger_villes(chemin):
   file = open(chemin, mode="r")
   lines = file.readlines()
   output = []

   for line in lines:
      values = shlex.split(line.replace('\n', ''))
      output.append(Ville(values[0], float(values[1]), float(values[2])))
   
   return output

villes = charger_villes("data.txt")

print(f'nb villes = {len(villes)}')
for ville in villes:
   print(ville)
# Out:
# nb villes = 627
# Paris(48.8567,2.3522)
# Bordeaux(44.84,-0.58)
# Marseille(43.2964,5.37)
# Lyon(45.76,4.84)
# Toulouse(43.6045,1.444)
# Nice(43.7034,7.2663)
# Nantes(47.2181,-1.5528)
# Montpellier(43.6119,3.8772)
# Strasbourg(48.5833,7.7458)
# Lille(50.6278,3.0583)
# Rennes(48.1147,-1.6794)
# Toulon(43.1258,5.9306)
# Reims(49.2628,4.0347)
# Saint-Ãƒâ€°tienne(45.4347,4.3903)
# Le Havre(49.49,0.1)
# Dijon(47.3167,5.0167)
# Grenoble(45.1715,5.7224)
# Angers(47.4736,-0.5542)
# Villeurbanne(45.7667,4.8803)
# NÃƒÂ®mes(43.8383,4.3597)
# Aix-en-Provence(43.5263,5.4454)
# Clermont-Ferrand(45.7831,3.0824)
# Le Mans(48.0077,0.1984)
# Brest(48.39,-4.49)
# Tours(47.3936,0.6892)
# Amiens(49.892,2.299)
# Annecy(45.916,6.133)
# Limoges(45.8353,1.2625)
# Metz(49.1203,6.1778)
# Boulogne-Billancourt(48.8352,2.2409)
# Perpignan(42.6986,2.8956)
# BesanÃƒÂ§on(47.24,6.02)
# OrlÃƒÂ©ans(47.9025,1.909)
# Rouen(49.4428,1.0886)
# Saint-Denis(48.9356,2.3539)
# Montreuil(48.8611,2.4436)
# Caen(49.1814,-0.3636)
# Argenteuil(48.95,2.25)
# Mulhouse(47.75,7.34)
# Nancy(48.6936,6.1846)
# Tourcoing(50.7239,3.1612)
# Roubaix(50.6901,3.1817)
# Nanterre(48.8988,2.1969)
# Vitry-sur-Seine(48.7875,2.3928)
# CrÃƒÂ©teil(48.7911,2.4628)
# Poitiers(46.58,0.34)
# Aubervilliers(48.9131,2.3831)
# Colombes(48.9236,2.2522)
# Dunkerque(51.0383,2.3775)
# Aulnay-sous-Bois(48.9386,2.4906)
# Versailles(48.8053,2.135)
# Courbevoic(48.8978,2.2531)
# La Rochelle(46.16,-1.15)
# Rueil-Malmaison(48.876,2.181)
# Champigny-sur-Marne(48.8172,2.5156)
# Pau(43.3,-0.37)
# MÃƒÂ©rignac(44.8386,-0.6436)
# Saint-Maur-des-FossÃƒÂ©s(48.7994,2.4997)
# Antibes(43.5808,7.1239)
# Ajaccio(41.9267,8.7369)
# Cannes(43.5513,7.0128)
# Saint-Nazaire(47.2736,-2.2139)
# Drancy(48.93,2.45)
# Noisy-le-Grand(48.8478,2.5528)
# Issy-les-Moulineaux(48.8239,2.27)
# Cergy(49.0361,2.0631)
# Levallois-Perret(48.895,2.2872)
# Calais(50.9481,1.8564)
# Pessac(44.8067,-0.6311)
# VÃƒÂ©nissieux(45.6969,4.8858)
# Clichy(48.9044,2.3064)
# Valence(44.9333,4.8917)
# Ivry-sur-Seine(48.8078,2.3747)
# Antony(48.7539,2.2975)
# Troyes(48.2997,4.0792)
# La Seyne-sur-Mer(43.1,5.883)
# Pantin(48.8966,2.4017)
# ChambÃƒÂ©ry(45.57,5.9118)
# Neuilly-sur-Seine(48.8881,2.2686)
# Sarcelles(48.9956,2.3808)
# Le Blanc-Mesnil(48.9387,2.4614)
# Maisons-Alfort(48.8058,2.4378)
# Lorient(47.75,-3.36)
# Villejuif(48.7919,2.3636)
# Bellevue(48.871,2.385)
# Beauvais(49.4303,2.0952)
# Meaux(48.9603,2.8883)
# Bobigny(48.9106,2.4397)
# Clamart(48.8014,2.2628)
# Vannes(47.6559,-2.7603)
# Chelles(48.8833,2.6)
# Ãƒâ€°vry(48.6238,2.4296)
# Ãƒâ€°pinay-sur-Seine(48.9553,2.3092)
# Saint-Ouen(48.9123,2.3342)
# Saint-Quentin(49.8486,3.2864)
# Bondy(48.9022,2.4828)
# Bayonne(43.49,-1.48)
# Corbeil-Essonnes(48.6139,2.482)
# Cagnes-sur-Mer(43.6644,7.1489)
# Vaulx-en-Velin(45.7768,4.9186)
# Sevran(48.9333,2.5333)
# Fontenay-sous-Bois(48.8517,2.4772)
# Sartrouville(48.9372,2.1644)
# Massy(48.7309,2.2713)
# Laval(48.0733,-0.7689)
# Saint-Herblain(47.2122,-1.6497)
# Gennevilliers(48.9333,2.3)
# Suresnes(48.87,2.22)
# Saint-Priest(45.6964,4.9439)
# Vincennes(48.8478,2.4392)
# Bastia(42.7008,9.4503)
# Montrouge(48.8172,2.3219)
# Ãƒâ€°vreux(49.02,1.15)
# La Courneuve(48.9322,2.3967)
# Charleville-MÃƒÂ©ziÃƒÂ¨res(49.7719,4.7161)
# Meudon(48.8123,2.2382)
# Choisy-le-Roi(48.763,2.409)
# Noisy-le-Sec(48.8894,2.4503)
# Livry-Gargan(48.9192,2.5361)
# Rosny-sous-Bois(48.8667,2.4833)
# Talence(44.8,-0.584)
# Belfort(47.64,6.85)
# Alfortville(48.805,2.4239)
# Chalon-sur-SaÃƒÂ´ne(46.7806,4.8528)
# SÃƒÂ¨te(43.4053,3.6975)
# Mantes-la-Jolie(48.9908,1.7172)
# Saint-Brieuc(48.5136,-2.7653)
# Tarbes(43.23,0.07)
# AlÃƒÂ¨s(44.1281,4.0817)
# ChÃƒÂ¢lons-en-Champagne(48.9575,4.365)
# Bagneux(48.7983,2.3137)
# Puteaux(48.885,2.2389)
# Caluire-et-Cuire(45.7953,4.8472)
# Bron(45.7386,4.9131)
# RezÃƒÂ©(47.1917,-1.5694)
# Valenciennes(50.3581,3.5233)
# ChÃƒÂ¢teauroux(46.8103,1.6911)
# Garges-lÃƒÂ¨s-Gonesse(48.9728,2.4008)
# Arras(50.292,2.78)
# Melun(48.5406,2.66)
# Le Cannet(43.5769,7.0194)
# Bourg-en-Bresse(46.2056,5.2289)
# Anglet(43.485,-1.5183)
# AngoulÃƒÂªme(45.65,0.16)
# Boulogne-sur-Mer(50.7264,1.6147)
# Wattrelos(50.7,3.217)
# Villenave-dÃ¢â‚¬â„¢Ornon(44.7806,-0.5658)
# Stains(48.95,2.3833)
# Gagny(48.8833,2.5333)
# Colomiers(43.6139,1.3367)
# Poissy(48.9294,2.0456)
# Douai(50.3714,3.08)
# Bagnolet(48.8692,2.4181)
# Marcq-en-Baroeul(50.6711,3.0972)
# Villepinte(48.955,2.541)
# Saint-Martin-dÃ¢â‚¬â„¢HÃƒÂ¨res(45.1672,5.7653)
# Chartres(48.456,1.484)
# Annemasse(46.1958,6.2364)
# Neuilly-sur-Marne(48.8537,2.549)
# Franconville(48.9889,2.2314)
# Savigny-sur-Orge(48.6797,2.3457)
# Thonon-les-Bains(46.3627,6.475)
# Ãƒâ€°chirolles(45.1436,5.7183)
# ChÃƒÂ¢tillon(48.8,2.29)
# Athis-Mons(48.7074,2.3889)
# Creil(49.2583,2.4833)
# Conflans-Sainte-Honorine(48.9992,2.0983)
# Villefranche-sur-SaÃƒÂ´ne(45.9833,4.7167)
# Meyzieu(45.7667,5.0036)
# Sainte-GeneviÃƒÂ¨ve-des-Bois(48.6369,2.3403)
# Villeneuve-Saint-Georges(48.7325,2.4497)
# ChÃƒÂ¢tenay-Malabry(48.7653,2.2781)
# Palaiseau(48.7145,2.2457)
# Roanne(46.0367,4.0689)
# Le Perreux-Sur-Marne(48.8422,2.5036)
# Schiltigheim(48.6078,7.75)
# Les Mureaux(48.9875,1.9172)
# Trappes(48.7775,2.0025)
# Nogent-sur-Marne(48.8375,2.4833)
# Houilles(48.9261,2.1892)
# MontluÃƒÂ§on(46.3408,2.6033)
# Romainville(48.884,2.435)
# Nevers(46.9933,3.1572)
# Lens(50.4322,2.8333)
# Agen(44.2049,0.6212)
# Pierrefitte-sur-Seine(48.9656,2.3614)
# Bezons(48.9261,2.2178)
# Aix-les-Bains(45.6886,5.915)
# Montigny-le-Bretonneux(48.7711,2.0333)
# Cambrai(50.1767,3.2356)
# LÃ¢â‚¬â„¢HaÃƒÂ¿-les-Roses(48.78,2.3374)
# Plaisir(48.8183,1.9472)
# Pontoise(49.0516,2.1017)
# Rillieux-la-Pape(45.8214,4.8983)
# Thiais(48.765,2.3923)
# Vigneux-sur-Seine(48.7001,2.417)
# Viry-ChÃƒÂ¢tillon(48.6713,2.375)
# Saint-Laurent-du-Var(43.668,7.188)
# BÃƒÂ¨gles(44.8086,-0.5478)
# Goussainville(49.0325,2.4747)
# Villiers-sur-Marne(48.8275,2.5447)
# Cachan(48.7919,2.3319)
# Savigny-le-Temple(48.5841,2.5832)
# Menton(43.775,7.5)
# Villemomble(48.8833,2.5)
# Malakoff(48.8172,2.2992)
# LiÃƒÂ©vin(50.4228,2.7786)
# La Garenne-Colombes(48.9056,2.2445)
# Ris-Orangis(48.6537,2.4161)
# Bois-Colombes(48.9175,2.2683)
# Clichy-sous-Bois(48.9102,2.5532)
# DÃƒÂ©cines-Charpieu(45.7694,4.9594)
# Saint-Cloud(48.84,2.22)
# Chatou(48.8897,2.1573)
# VandÃ…â€œuvre-lÃƒÂ¨s-Nancy(48.6567,6.1683)
# PÃƒÂ©rigueux(45.1929,0.7217)
# Charenton-le-Pont(48.8265,2.405)
# Tournefeuille(43.5853,1.3442)
# Guyancourt(48.7714,2.0739)
# Le Plessis-Robinson(48.7811,2.2633)
# Draveil(48.6852,2.408)
# Maubeuge(50.2775,3.9734)
# Ermont(48.9922,2.2603)
# Sotteville-lÃƒÂ¨s-Rouen(49.4092,1.09)
# Villiers-le-Bel(49.0094,2.3911)
# Fresnes(48.755,2.3221)
# Soissons(49.3817,3.3236)
# Yerres(48.7171,2.4881)
# Saint-Ãƒâ€°tienne-du-Rouvray(49.3786,1.105)
# Dieppe(49.925,1.075)
# Saint-SÃƒÂ©bastien-sur-Loire(47.2081,-1.5014)
# Vallauris(43.5805,7.0538)
# Vanves(48.8208,2.2897)
# Lomme(50.6358,3.0142)
# Limeil-BrÃƒÂ©vannes(48.7464,2.4883)
# Montfermeil(48.9,2.5667)
# Le Chesnay(48.8211,2.1311)
# Sucy-en-Brie(48.7697,2.5228)
# Grigny(48.6562,2.3849)
# Lambersart(50.65,3.025)
# BrÃƒÂ©tigny-sur-Orge(48.6114,2.3059)
# Taverny(49.0264,2.2275)
# Oullins(45.7142,4.8075)
# Villeparisis(48.9503,2.6025)
# Cenon(44.8578,-0.5317)
# Sannois(48.9722,2.2578)
# Cormeilles-en-Parisis(48.9739,2.2014)
# Bussy-Saint-Georges(48.8422,2.6983)
# Blagnac(43.6364,1.3906)
# Ãƒâ€°lancourt(48.7847,1.9589)
# Le Grand-Quevilly(49.4072,1.0531)
# La Garde(43.1256,6.0108)
# Gradignan(44.7725,-0.6156)
# Vichy(46.1278,3.4267)
# Biarritz(43.48,-1.56)
# Champs-Sur-Marne(48.8529,2.6027)
# ArmentiÃƒÂ¨res(50.6881,2.8811)
# MontbÃƒÂ©liard(47.51,6.8)
# AlenÃƒÂ§on(48.4306,0.0931)
# Brunoy(48.6979,2.5044)
# Eaubonne(48.9922,2.2806)
# Villeneuve-la-Garenne(48.9372,2.3278)
# Cherbourg(49.63,-1.62)
# Saint-Ouen-lÃ¢â‚¬â„¢AumÃƒÂ´ne(49.0447,2.1111)
# BÃƒÂ©thune(50.5303,2.6408)
# Castelnau-le-Lez(43.6369,3.9019)
# Fontenay-aux-Roses(48.7893,2.2888)
# Orly(48.7439,2.3928)
# Le Kremlin-BicÃƒÂªtre(48.81,2.3581)
# Eysines(44.8853,-0.65)
# Le Bouscat(44.8651,-0.5996)
# Rodez(44.3506,2.575)
# Les Pavillons-sous-Bois(48.9,2.5)
# La Valette-du-Var(43.1383,5.9831)
# Montgeron(48.7039,2.4605)
# Les Lilas(48.88,2.42)
# Lormont(44.8792,-0.5217)
# Maisons-Laffitte(48.9469,2.1456)
# Roissy-en-Brie(48.7906,2.6519)
# Loos(50.6128,3.0144)
# Fontaine(45.1939,5.6856)
# Dammarie-lÃƒÂ¨-Lys(48.5177,2.6402)
# VÃƒÂ©lizy-Villacoublay(48.7834,2.1834)
# Tassin-la-Demi-Lune(45.764,4.78)
# SÃƒÂ¨vres(48.8239,2.2117)
# Montigny-lÃƒÂ¨s-Cormeilles(48.9944,2.1958)
# Deuil-la-Barre(48.9767,2.3272)
# La Madeleine(50.6558,3.071)
# Torcy(48.8502,2.6508)
# Montereau-faut-Yonne(48.3853,2.9508)
# Combs-la-Ville(48.67,2.56)
# HÃƒÂ©rouville-Saint-Clair(49.2044,-0.3253)
# Montmorency(48.9906,2.3228)
# Sainte-Foy-lÃƒÂ¨s-Lyon(45.7336,4.8025)
# Montigny-lÃƒÂ¨s-Metz(49.1006,6.1539)
# Le Petit-Quevilly(49.4311,1.0539)
# Saint-Jean-de-Braye(47.9128,1.9719)
# Arcueil(48.8075,2.3361)
# Mons-en-Baroeul(50.6369,3.1103)
# Fleury-les-Aubrais(47.9312,1.921)
# Saint-Michel-sur-Orge(48.6303,2.3025)
# Neuilly-Plaisance(48.8619,2.5064)
# Nogent-sur-Oise(49.2756,2.4683)
# Mantes-la-Ville(48.975,1.7117)
# AchÃƒÂ¨res(48.9602,2.0684)
# Saint-MandÃƒÂ©(48.8422,2.4186)
# Villeneuve-le-Roi(48.7333,2.4167)
# Saint-Cyr-lÃ¢â‚¬â„¢Ãƒâ€°cole(48.8008,2.0633)
# Saint-Genis-Laval(45.6953,4.7931)
# Saint-Gratien(48.9719,2.2828)
# Wasquehal(50.6694,3.1308)
# Halluin(50.7836,3.1256)
# Bourg-la-Reine(48.7796,2.3151)
# Morsang-sur-Orge(48.6618,2.3461)
# Croix(50.6781,3.1508)
# Coudekerque-Branche(51.0253,2.3917)
# FougÃƒÂ¨res(48.3525,-1.1986)
# Denain(50.3294,3.3958)
# Longjumeau(48.6943,2.2958)
# Sceaux(48.7786,2.2906)
# Saint-Pol-sur-Mer(51.0314,2.3439)
# La Celle-Saint-Cloud(48.8411,2.1344)
# Joinville-le-Pont(48.8214,2.4728)
# Cugnaux(43.5386,1.3444)
# Chevilly-Larue(48.7663,2.3533)
# Lingolsheim(48.56,7.68)
# Le Plessis-TrÃƒÂ©vise(48.8111,2.5717)
# Le MÃƒÂ©e-sur-Seine(48.5333,2.6289)
# Mont-Saint-Aignan(49.463,1.0883)
# Chaville(48.8086,2.1886)
# Chilly-Mazarin(48.7025,2.3125)
# Lisieux(49.15,0.23)
# Ronchin(50.6053,3.0886)
# Saint-Fons(45.7086,4.8533)
# Moulins(46.5653,3.3333)
# Villefontaine(45.6142,5.1494)
# Gentilly(48.8133,2.3444)
# Bonneuil-sur-Marne(48.7742,2.4875)
# Hem(50.6558,3.1886)
# Maurepas(48.76,1.95)
# Meylan(45.2092,5.78)
# Ãƒâ€°ragny(49.0181,2.0922)
# Hellemmes-Lille(50.6167,3.1167)
# Juvisy-sur-Orge(48.6889,2.3783)
# ChenneviÃƒÂ¨res-sur-Marne(48.7983,2.5339)
# Ãƒâ€°cully(45.7753,4.7783)
# Cran-GÃƒÂ©vrier(45.9097,6.1107)
# CarriÃƒÂ¨res-sous-Poissy(48.9486,2.0394)
# RosendaÃƒÂ«l(51.0413,2.4037)
# FÃƒÂ¢ches-Thumesnil(50.5994,3.0744)
# Soisy-sous-Montmorency(48.9886,2.3006)
# Bischheim(48.6144,7.7528)
# Garches(48.8461,2.1889)
# Hendaye(43.36,-1.77)
# Floirac(44.8375,-0.5247)
# Limay(48.9942,1.7367)
# Boissy-Saint-LÃƒÂ©ger(48.7511,2.5106)
# Le Pontet(43.965,4.8606)
# ChamaliÃƒÂ¨res(45.7744,3.0678)
# Bry-sur-Marne(48.8411,2.5222)
# Les Clayes-sous-Bois(48.8167,1.9833)
# LÃ¢â‚¬â„¢Isle-dÃ¢â‚¬â„¢Abeau(45.6233,5.2305)
# Jouy-le-Moutier(49.0117,2.0397)
# Cluses(46.0611,6.5794)
# Firminy(45.3889,4.2878)
# Lons-le-Saunier(46.6753,5.5544)
# Saint-Ãƒâ€°grÃƒÂ¨ve(45.2325,5.6836)
# Viroflay(48.8,2.167)
# Octeville(49.6269,-1.6431)
# Le PrÃƒÂ©-Saint-Gervais(48.8833,2.4)
# Saint-Jean-de-la-Ruelle(47.9139,1.8745)
# Marly-le-Roi(48.8675,2.0947)
# Domont(49.0283,2.3275)
# VaurÃƒÂ©al(49.0353,2.0328)
# Orsay(48.6993,2.1875)
# Saint-Leu-la-ForÃƒÂªt(49.0175,2.2472)
# Verneuil-sur-Seine(48.9806,1.9747)
# Petite-Synthe(51.0194,2.3467)
# Saint-Julien-en-Genevois(46.1436,6.0811)
# Le Pecq(48.8969,2.1069)
# Le VÃƒÂ©sinet(48.8923,2.1331)
# LucÃƒÂ©(48.4389,1.4658)
# Wattignies(50.5856,3.0439)
# Noisiel(48.8547,2.6289)
# Bois-dÃ¢â‚¬â„¢Arcy(48.8,2.03)
# Rive-de-Gier(45.5303,4.6178)
# Saint-Brice-sous-ForÃƒÂªt(48.9992,2.3578)
# Francheville(45.7364,4.7636)
# Longwy(49.52,5.7606)
# Vesoul(47.6231,6.1558)
# Montargis(47.9978,2.7333)
# CarriÃƒÂ¨res-sur-Seine(48.9108,2.2889)
# Ramonville-Saint-Agne(43.5434,1.4787)
# Castanet-Tolosan(43.5164,1.4989)
# Le Raincy(48.9,2.5167)
# Le Bourget(48.9353,2.4256)
# Illzach(47.7831,7.3486)
# Montmagny(48.9744,2.3467)
# Villers-lÃƒÂ¨s-Nancy(48.6731,6.1547)
# Haubourdin(50.6097,2.9878)
# Dinan(48.4564,-2.0489)
# Lognes(48.836,2.6278)
# Saint-Maurice(48.8156,2.4592)
# VerriÃƒÂ¨res-le-Buisson(48.7464,2.2674)
# Arnouville-lÃƒÂ¨s-Gonesse(48.9878,2.4175)
# Saint-Genis-Pouilly(46.2437,6.025)
# Les Sables-dÃ¢â‚¬â„¢Olonne(46.4972,-1.7833)
# Montesson(48.9085,2.1496)
# Valenton(48.745,2.4672)
# ChenÃƒÂ´ve(47.2917,5.0081)
# Bois-Guillaume(49.4614,1.1092)
# Auray(47.6686,-2.9814)
# Persan(49.1542,2.2719)
# Fleury-MÃƒÂ©rogis(48.63,2.362)
# Audincourt(47.4836,6.8403)
# MontÃƒÂ©vrain(48.875,2.7456)
# BillÃƒÂ¨re(43.3031,-0.3906)
# Lys-lÃƒÂ¨s-Lannoy(50.6722,3.2153)
# Avon(48.4097,2.7161)
# Vaires-sur-Marne(48.8667,2.65)
# Courcouronnes(48.6239,2.4294)
# Fontenay-le-Fleury(48.8144,2.0494)
# Anzin(50.3722,3.505)
# Ostwald(48.5425,7.7103)
# Outreau(50.7044,1.5947)
# AndrÃƒÂ©sy(48.9817,2.0592)
# Morangis(48.7055,2.3326)
# Kingersheim(47.7922,7.3386)
# Mouvaux(50.7039,3.1414)
# Saint-AndrÃƒÂ©(50.6608,3.045)
# Saint-AndrÃƒÂ©-les-Vergers(48.2806,4.0547)
# Bayeux(49.2794,-0.7028)
# Beausoleil(43.7425,7.4244)
# LÃ¢â‚¬â„¢Union(43.6575,1.4853)
# Bully-les-Mines(50.4425,2.7253)
# Riedisheim(47.7489,7.3675)
# Marly(50.349,3.545)
# Craponne(45.7453,4.7233)
# Talant(47.3372,5.0064)
# Ãƒâ€°pinay-sous-SÃƒÂ©nart(48.6948,2.5147)
# Le Relecq-Kerhuon(48.4092,-4.3956)
# Villecresnes(48.7214,2.5342)
# HÃ…â€œnheim(48.625,7.7553)
# Vitry-le-FranÃƒÂ§ois(48.7256,4.5853)
# Enghien-les-Bains(48.9697,2.3081)
# MÃƒÂ©ricourt(50.4031,2.8667)
# Yvetot(49.62,0.75)
# Dugny(48.95,2.4167)
# Bruay-sur-lÃ¢â‚¬â„¢Escaut(50.3989,3.5403)
# Saint-Germain-lÃƒÂ¨s-Arpajon(48.5946,2.2558)
# Arpajon(48.5901,2.2476)
# Arcachon(44.65,-1.17)
# Saint-Jean(43.6664,1.5058)
# Marquette-lÃƒÂ¨s-Lille(50.6764,3.0667)
# Cesson(48.5633,2.6053)
# Stiring-Wendel(49.2,6.93)
# Maromme(49.4825,1.0428)
# Ferney-Voltaire(46.2558,6.1081)
# Bondoufle(48.6145,2.3807)
# Le Pont-de-Claix(45.1289,5.6989)
# Ãƒâ€°pinay-sur-Orge(48.6726,2.3239)
# DÃƒÂ©ville-lÃƒÂ¨s-Rouen(49.47,1.05)
# Chanteloup-les-Vignes(48.9792,2.0319)
# Voisins-le-Bretonneux(48.7592,2.0517)
# Ville-dÃ¢â‚¬â„¢Avray(48.8261,2.1933)
# Beaumont(45.7525,3.0836)
# Flers-lez-Lille(50.6333,3.1333)
# Tinqueux(49.2509,3.9918)
# Ormesson-sur-Marne(48.7858,2.5383)
# Pierre-BÃƒÂ©nite(45.7036,4.8242)
# Clermont(49.3797,2.4133)
# Thorigny-sur-Marne(48.8788,2.7075)
# Croissy-sur-Seine(48.8783,2.1433)
# Villeneuve-Tolosane(43.5247,1.3425)
# Avranches(48.685,-1.3556)
# Pfastatt(47.7697,7.3025)
# Igny(48.7421,2.2261)
# Oignies(50.47,2.9944)
# Gaillard(46.1858,6.2083)
# Neuville-en-Ferrain(50.7472,3.1589)
# Caudebec-lÃƒÂ¨s-Elbeuf(49.2817,1.0222)
# Saint-Max(48.7017,6.2072)
# Villerupt(49.4697,5.9286)
# Auchel(50.5086,2.4744)
# Vernouillet(48.9728,1.9842)
# Aniche(50.3306,3.2519)
# Eybens(45.1494,5.7508)
# Fosses(49.0989,2.5075)
# MaxÃƒÂ©ville(48.7122,6.1639)
# Montigny-en-Gohelle(50.4286,2.9308)
# Grigny(45.6092,4.7906)
# DarnÃƒÂ©tal(49.4453,1.1519)
# Serris(48.8456,2.7878)
# Sallaumines(50.4203,2.8631)
# Neuville-lÃƒÂ¨s-Dieppe(49.9267,1.1014)
# Beaumont-sur-Oise(49.1431,2.2872)
# Leers(50.6825,3.2447)
# Ãƒâ€°zanville(49.0286,2.3617)
# PÃƒÂ©rols(43.5658,3.9511)
# Crosne(48.7164,2.458)
# Quincy-sous-SÃƒÂ©nart(48.6714,2.5407)
# Jarville-la-Malgrange(48.67,6.2067)
# Aucamville(43.6697,1.4311)
# Hagondange(49.255,6.1686)
# Le CrÃƒÂ¨s(43.6481,3.9397)
# Bures-sur-Yvette(48.6969,2.1639)
# Ãƒâ€°vian-les-Bains(46.3833,6.5833)
# Ville-la-Grand(46.2031,6.2475)
# Beauchamp(49.0144,2.1906)
# Magny-le-Hongre(48.8631,2.8133)
# Bougival(48.8667,2.1333)
# Tomblaine(48.6833,6.2167)
# Le Portel(50.7075,1.5744)
# Fontaine-lÃƒÂ¨s-Dijon(47.3433,5.0206)
# Boucau(43.5244,-1.4853)
# Essey-lÃƒÂ¨s-Nancy(48.7067,6.2231)
# Wingles(50.4947,2.8561)
# MontlhÃƒÂ©ry(48.6392,2.2722)
# LÃ¢â‚¬â„¢ÃƒÅ½le-Saint-Denis(48.9333,2.3333)
# Vaucresson(48.8392,2.1578)
# La Salvetat-Saint-Gilles(43.5769,1.2722)
# PÃƒÂ©renchies(50.6686,2.9731)
# Saint-Aubin-lÃƒÂ¨s-Elbeuf(49.2991,1.0127)
# Groslay(48.9875,2.3453)
# Le Plessis-Bouchard(49.0033,2.2375)
# Meythet(45.9156,6.0936)
# Terrenoire(45.4343,4.4377)
# Harfleur(49.5072,0.1989)
# Carbon-Blanc(44.8958,-0.5053)
# Courcelles-les-Lens(50.4186,3.0189)
# Bihorel(49.4553,1.1169)
# La Tour-du-Pin(45.565,5.4444)
# Souffelweyersheim(48.6356,7.7417)
# Billy-Montigny(50.4519,2.9128)
# La Ville-du-Bois(48.6611,2.2687)
# Coulaines(48.0267,0.2042)
# Boussy-Saint-Antoine(48.6886,2.5298)
# Le Mesnil-Esnard(49.4117,1.1428)
# Talange(49.2372,6.175)
# Cappelle-la-Grande(50.999,2.364)
# Beauzelle(43.6664,1.3783)
# Vaujours(48.9333,2.5667)
# Saint-Germain-lÃƒÂ¨s-Corbeil(48.6205,2.4879)
# Terville(49.3453,6.1347)
# Waziers(50.387,3.113)
# Huningue(47.5919,7.5844)
# Villemoisson-sur-Orge(48.6618,2.3298)
# Sainte-Adresse(49.51,0.08)
# Guingamp(48.5633,-3.15)
# Fontaines-sur-SaÃƒÂ´ne(45.836,4.845)
# Liancourt(49.3317,2.4661)
# Courtry(48.9175,2.6031)
# Gournay-sur-Marne(48.8606,2.5772)
# Sathonay-Camp(45.8242,4.8747)
# Jacou(43.6614,3.9122)
# Beuvrages(50.3867,3.5064)
# Ãƒâ€°gly(48.5798,2.2218)
# Carnoux-en-Provence(43.2564,5.5644)
# Grenay(50.4528,2.7439)
# Luisant(48.4325,1.4772)
# Noyelles-sous-Lens(50.4311,2.8736)
# La BassÃƒÂ©e(50.5342,2.8081)
# Neuves-Maisons(48.6169,6.1044)
# La MulatiÃƒÂ¨re(45.7281,4.8122)
# BouffÃƒÂ©mont(49.0442,2.3)
# La Penne-sur-Huveaune(43.2806,5.5158)
# JÃ…â€œuf(49.2306,6.0097)
# Cognin(45.563,5.9)
# La Montagne(47.1833,-1.6833)
# Bonsecours(49.43,1.13)
# Saint-Alban(43.6928,1.4156)
# LÃ¢â‚¬â„¢Arbresle(45.8364,4.6178)
# Esbly(48.9067,2.8125)
# Le Mesnil-le-Roi(48.9375,2.1275)
# FouquiÃƒÂ¨res-lÃƒÂ¨s-Lens(50.4294,2.9136)
# La VerriÃƒÂ¨re(48.7592,1.9631)
# Ambilly(46.194,6.223)
# Saint-Priest-en-Jarez(45.475,4.3789)
# Magnanville(48.9681,1.6828)
# Pont-de-ChÃƒÂ©ruy(45.7514,5.1736)
# Menucourt(49.0278,1.9819)
# Ablon-sur-Seine(48.7256,2.4211)
# Champagne-au-Mont-dÃ¢â‚¬â„¢Or(45.795,4.791)
# Palavas-les-Flots(43.5303,3.9314)
# Saintry-sur-Seine(48.5962,2.4929)
# Saint-AndrÃƒÂ©-de-la-Roche(43.7411,7.2883)
# Longueau(49.8708,2.3569)
# Le Port-Marly(48.8967,2.1106)
# Oberhausbergen(48.6072,7.6861)
# Heillecourt(48.6531,6.195)
# CrÃƒÂ©gy-lÃƒÂ¨s-Meaux(48.9794,2.8792)
# Loison-sous-Lens(50.4389,2.8533)
# Montaigu(46.9736,-1.3086)
# Bassens(45.5756,5.94)
# Grand-Fort-Philippe(50.99,2.11)
# Mandres-les-Roses(48.7022,2.5444)
# La Frette-sur-Seine(48.975,2.1794)
# Le Ban-Saint-Martin(49.1225,6.1511)
# Saint-Nicolas(50.3031,2.7781)
# Villiers-sur-Orge(48.6574,2.3001)
# Cap-dÃ¢â‚¬â„¢Ail(43.7219,7.4064)
# Nilvange(49.3428,6.0508)
# Leuville-sur-Orge(48.6175,2.2658)
# Jacob-Bellecombette(45.5582,5.91)
# Valras-Plage(43.2478,3.2917)
# Avesnes-sur-Helpe(50.1244,3.9267)
# Ascq(50.6167,3.1667)
# Longeville-lÃƒÂ¨s-Metz(49.1153,6.1361)
# Neuville-Saint-RÃƒÂ©my(50.1883,3.2231)
# Toufflers(50.6617,3.2303)
# Mareil-Marly(48.8825,2.0775)
# Lourches(50.315,3.356)
# Beaulieu-sur-Mer(43.705,7.33)
# Sochaux(47.52,6.83)
# Bergues(50.9692,2.435)
# Barby(45.5722,5.9784)
# Fort-Mardyck(51.031,2.3061)
# Neauphle-le-ChÃƒÂ¢teau(48.8153,1.9031)
# Saint-MammÃƒÂ¨s(48.3893,2.808)
# Les NoÃƒÂ«s-prÃƒÂ¨s-Troyes(48.3031,4.0419)
# Pont-Ã -Vendin(50.4744,2.8894)
# Rouelles(49.5208,0.1608)
# PaimbÃ…â€œuf(47.2833,-2.0333)
# Courchelettes(50.34,3.06)
# Ãƒâ€°leu-dit-Leauwette(50.4217,2.8119)
# Port-Louis(47.7072,-3.3519)
# Sainte-Foy-la-Grande(44.84,0.22)

# %% [markdown]
# #### Calcul des distances

# %%
import math

# calcul la distance euclidienne entre 2 villes
def distance(villeA: Ville, villeB: Ville):
   d = math.sqrt(math.pow(villeA.longitude - villeB.longitude, 2) + math.pow(villeA.latitude - villeB.latitude, 2))
   return d


# distance entre Paris et Bordeaux
d1 = distance(villes[0], villes[1])
print(f"distance entre Paris et Bordeaux: {d1}")

# distance entre Marseille et Lyon
d1 = distance(villes[2], villes[3])
print(f"distance entre Marseille et Lyon: {d1}")

# distance entre Toulouse et Nice
d1 = distance(villes[4], villes[5])
print(f"distance entre Toulouse et Nice: {d1}")
# Out:
# distance entre Paris et Bordeaux: 4.973095186098889
# distance entre Marseille et Lyon: 2.519965269601944
# distance entre Toulouse et Nice: 5.823139917604591

# %% [markdown]
# #### Heuristique simple pour le Voyageur de Commerce

# %%
from typing import List

# Define a Segment class which represents the route between two cities
class Segment:
   start: Ville
   end: Ville
   distance: float

   def __init__(self, villeA,  villeB, distance):
      self.start = villeA
      self.end = villeB
      self.distance = distance

   def __str__(self):
      return f"{self.start.name} -> {self.distance} -> {self.end.name}"

# return a tuple containing the index and distance of the closest city to the one in start parameter
def get_next_ville(start, villes):

   shortest_distance = -1
   ville_index = 0
   for idx, ville in enumerate(villes):
      dist = distance(start, ville)
      if(shortest_distance == -1 or dist < shortest_distance):
         ville_index = idx
         shortest_distance = dist

   return (ville_index, shortest_distance)

def itineraire_greedy(villes: List[Ville]):

   left_to_visit: List[Ville] = villes[1:]
   current = villes[0]
   route: List[Segment] = []

   while len(left_to_visit) > 0:
      result = get_next_ville(current, left_to_visit)
      selected_ville = left_to_visit.pop(result[0])
      distance = result[1]
      route.append(Segment(current, selected_ville, distance))
      current = selected_ville
   
   return route

route = itineraire_greedy(villes)


print(f"total distance = {sum(seg.distance for seg in route)}")

path = route[0].start.name
for segment in route:
   path += ' -> ' + segment.end.name

print(path)

# Problématiques :
# Test de toutes les villes possibles à chaque étape, on pourrait faire une première étape 
# Potentiels aller-retours entre des villes là où faire une boucle pourrait être plus efficace
# Out:
# total distance = 112.83477591655198
# Paris -> Bellevue -> Le PrÃƒÂ©-Saint-Gervais -> Pantin -> Les Lilas -> Bagnolet -> Romainville -> Noisy-le-Sec -> Bobigny -> Drancy -> Le Blanc-Mesnil -> Aulnay-sous-Bois -> Bondy -> Les Pavillons-sous-Bois -> Villemomble -> Neuilly-Plaisance -> Le Perreux-Sur-Marne -> Bry-sur-Marne -> Champigny-sur-Marne -> Saint-Maur-des-FossÃƒÂ©s -> Bonneuil-sur-Marne -> Limeil-BrÃƒÂ©vannes -> Valenton -> Villeneuve-Saint-Georges -> Crosne -> Montgeron -> Yerres -> Brunoy -> Ãƒâ€°pinay-sous-SÃƒÂ©nart -> Boussy-Saint-Antoine -> Mandres-les-Roses -> Villecresnes -> Boissy-Saint-LÃƒÂ©ger -> Sucy-en-Brie -> Ormesson-sur-Marne -> ChenneviÃƒÂ¨res-sur-Marne -> Villiers-sur-Marne -> Noisy-le-Grand -> Neuilly-sur-Marne -> Gournay-sur-Marne -> Champs-Sur-Marne -> Noisiel -> Lognes -> Torcy -> Vaires-sur-Marne -> Chelles -> Courtry -> Villeparisis -> Vaujours -> Clichy-sous-Bois -> Montfermeil -> Livry-Gargan -> Sevran -> Villepinte -> Le Raincy -> Gagny -> Rosny-sous-Bois -> Fontenay-sous-Bois -> Nogent-sur-Marne -> Joinville-le-Pont -> Saint-Maurice -> Maisons-Alfort -> Alfortville -> Charenton-le-Pont -> Saint-MandÃƒÂ© -> Vincennes -> Montreuil -> CrÃƒÂ©teil -> Choisy-le-Roi -> Thiais -> Orly -> Villeneuve-le-Roi -> Ablon-sur-Seine -> Vigneux-sur-Seine -> Draveil -> Athis-Mons -> Juvisy-sur-Orge -> Viry-ChÃƒÂ¢tillon -> Grigny -> Ris-Orangis -> Courcouronnes -> Ãƒâ€°vry -> Bondoufle -> Fleury-MÃƒÂ©rogis -> Sainte-GeneviÃƒÂ¨ve-des-Bois -> Morsang-sur-Orge -> Villemoisson-sur-Orge -> Ãƒâ€°pinay-sur-Orge -> Savigny-sur-Orge -> Morangis -> Chilly-Mazarin -> Longjumeau -> Villiers-sur-Orge -> Saint-Michel-sur-Orge -> BrÃƒÂ©tigny-sur-Orge -> Leuville-sur-Orge -> MontlhÃƒÂ©ry -> La Ville-du-Bois -> Palaiseau -> Massy -> VerriÃƒÂ¨res-le-Buisson -> ChÃƒÂ¢tenay-Malabry -> Sceaux -> Fontenay-aux-Roses -> ChÃƒÂ¢tillon -> Malakoff -> Vanves -> Issy-les-Moulineaux -> Clamart -> Le Plessis-Robinson -> Meudon -> Boulogne-Billancourt -> Saint-Cloud -> SÃƒÂ¨vres -> Ville-dÃ¢â‚¬â„¢Avray -> Chaville -> Viroflay -> VÃƒÂ©lizy-Villacoublay -> Versailles -> Le Chesnay -> La Celle-Saint-Cloud -> Vaucresson -> Garches -> Rueil-Malmaison -> Chatou -> Croissy-sur-Seine -> Bougival -> Le VÃƒÂ©sinet -> Le Port-Marly -> Le Pecq -> Marly-le-Roi -> Mareil-Marly -> Poissy -> CarriÃƒÂ¨res-sous-Poissy -> AchÃƒÂ¨res -> AndrÃƒÂ©sy -> Chanteloup-les-Vignes -> Jouy-le-Moutier -> VaurÃƒÂ©al -> Cergy -> Ãƒâ€°ragny -> Conflans-Sainte-Honorine -> Saint-Ouen-lÃ¢â‚¬â„¢AumÃƒÂ´ne -> Pontoise -> Beauchamp -> Montigny-lÃƒÂ¨s-Cormeilles -> Cormeilles-en-Parisis -> La Frette-sur-Seine -> Sartrouville -> Maisons-Laffitte -> Le Mesnil-le-Roi -> Montesson -> Houilles -> Nanterre -> Bezons -> La Garenne-Colombes -> Courbevoic -> Neuilly-sur-Seine -> Levallois-Perret -> CarriÃƒÂ¨res-sur-Seine -> Clichy -> Saint-Ouen -> LÃ¢â‚¬â„¢ÃƒÅ½le-Saint-Denis -> Villeneuve-la-Garenne -> Ãƒâ€°pinay-sur-Seine -> Enghien-les-Bains -> Soisy-sous-Montmorency -> Eaubonne -> Ermont -> Sannois -> Argenteuil -> Colombes -> Bois-Colombes -> Gennevilliers -> Saint-Gratien -> Montmorency -> Deuil-la-Barre -> Montmagny -> Groslay -> Saint-Brice-sous-ForÃƒÂªt -> Sarcelles -> Villiers-le-Bel -> Arnouville-lÃƒÂ¨s-Gonesse -> Garges-lÃƒÂ¨s-Gonesse -> Dugny -> Le Bourget -> La Courneuve -> Stains -> Pierrefitte-sur-Seine -> Saint-Denis -> Aubervilliers -> Ivry-sur-Seine -> Le Kremlin-BicÃƒÂªtre -> Gentilly -> Arcueil -> Cachan -> LÃ¢â‚¬â„¢HaÃƒÂ¿-les-Roses -> Chevilly-Larue -> Villejuif -> Vitry-sur-Seine -> Montrouge -> Bagneux -> Bourg-la-Reine -> Fresnes -> Antony -> Igny -> Orsay -> Bures-sur-Yvette -> Guyancourt -> Voisins-le-Bretonneux -> Montigny-le-Bretonneux -> Bois-dÃ¢â‚¬â„¢Arcy -> Fontenay-le-Fleury -> Saint-Cyr-lÃ¢â‚¬â„¢Ãƒâ€°cole -> Trappes -> La VerriÃƒÂ¨re -> Maurepas -> Ãƒâ€°lancourt -> Plaisir -> Les Clayes-sous-Bois -> Neauphle-le-ChÃƒÂ¢teau -> Les Mureaux -> Verneuil-sur-Seine -> Vernouillet -> Menucourt -> Taverny -> Saint-Leu-la-ForÃƒÂªt -> Le Plessis-Bouchard -> Franconville -> BouffÃƒÂ©mont -> Domont -> Ãƒâ€°zanvill ...
